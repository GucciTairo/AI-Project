# %%
import os
from PIL import Image, UnidentifiedImageError

# %%
class_folders = [
    "/media/tairo/Storages/AIProject/AboutModel/TraAI/Data/train/Bacterial Spot",
    "/media/tairo/Storages/AIProject/AboutModel/TraAI/Data/train/Early Blight",
    "/media/tairo/Storages/AIProject/AboutModel/TraAI/Data/train/Yellow Leaf Curl"
]

# %%
TARGET_SIZE = (224, 224)
IMAGE_EXTENSIONS = ('.png', '.jpg', '.jpeg', '.gif', '.bmp', '.tiff')

# %%
def resize_images_in_folders(folders_to_process, target_size):
    for class_folder_path in folders_to_process:
        print(f"Processing directory: {class_folder_path}")

        if not os.path.isdir(class_folder_path):
            print(f"  Error: {class_folder_path} not a valid directory")
            continue
        images_processed_count = 0
        images_failed_count = 0

        try:
            filenames = os.listdir(class_folder_path)
        except FileNotFoundError:
            print(f"  Error: Directory not found: {class_folder_path}")
            continue
        except Exception as e:
            print(f"  Error listing files in {class_folder_path}: {e}. Skipping.")
            continue

        if not filenames:
            print(f"  No files found in {class_folder_path}.")
            continue

        for filename in filenames:
            if filename.lower().endswith(IMAGE_EXTENSIONS):
                image_path = os.path.join(class_folder_path, filename)
                try:
                    img = Image.open(image_path)

                    # Resize the image
                    # Image.Resampling.LANCZOS is a high-quality downsampling filter
                    # For older Pillow versions, Image.ANTIALIAS might be used
                    img_resized = img.resize(target_size, Image.Resampling.LANCZOS)

                    # Save the resized image, overwriting the original
                    img_resized.save(image_path)
                    print(f"    Resized and saved: {filename} to {target_size[0]}x{target_size[1]}")
                    images_processed_count += 1

                except UnidentifiedImageError:
                    print(f"Error: Cannot identify image file: {filename}")
                    images_failed_count += 1
                except FileNotFoundError:
                    print(f"Error: Image file not found: {image_path}")
                    images_failed_count += 1
                except Exception as e:
                    print(f"Error processing {filename}: {e}")
                    images_failed_count += 1
        print(f"  Finished processing {class_folder_path}.")
        print(f"  Successfully resized: {images_processed_count} images.")
        print(f"  Failed to process: {images_failed_count} images.")

# %%
if __name__ == "__main__":
    print("Starting image resizing process...")
    print(f"Target size for all images: {TARGET_SIZE[0]}x{TARGET_SIZE[1]} pixels.")
    print("WARNING: This script will OVERWRITE original image files.")

    resize_images_in_folders(class_folders, TARGET_SIZE)
    print("=" * 50)
    print("Image resizing process complete.")
# Out:
# Starting image resizing process...
# Target size for all images: 224x224 pixels.
# WARNING: This script will OVERWRITE original image files.
# Processing directory: /media/tairo/Storages/AIProject/AboutModel/TraAI/Data/train/Bacterial Spot
#     Resized and saved: BacterialSpot(2871).JPG to 224x224
#     Resized and saved: BacterialSpot(1055).JPG to 224x224
#     Resized and saved: BacterialSpot(2742).JPG to 224x224
#     Resized and saved: BacterialSpot(347).JPG to 224x224
#     Resized and saved: BacterialSpot(200).JPG to 224x224
#     Resized and saved: BacterialSpot(665).JPG to 224x224
#     Resized and saved: BacterialSpot(1469).jpg to 224x224
#     Resized and saved: BacterialSpot(3042).JPG to 224x224
#     Resized and saved: BacterialSpot(1719).jpg to 224x224
#     Resized and saved: BacterialSpot(798).JPG to 224x224
#     Resized and saved: BacterialSpot(260).JPG to 224x224
#     Resized and saved: BacterialSpot(1324).jpg to 224x224
#     Resized and saved: BacterialSpot(514).JPG to 224x224
#     Resized and saved: BacterialSpot(663).JPG to 224x224
#     Resized and saved: BacterialSpot(1708).jpg to 224x224
#     Resized and saved: BacterialSpot(2621).jpg to 224x224
#     Resized and saved: BacterialSpot(1442).jpg to 224x224
#     Resized and saved: BacterialSpot(1566).jpg to 224x224
#     Resized and saved: BacterialSpot(132).JPG to 224x224
#     Resized and saved: BacterialSpot(666).JPG to 224x224
#     Resized and saved: BacterialSpot(3446).JPG to 224x224
#     Resized and saved: BacterialSpot(1591).jpg to 224x224
#     Resized and saved: BacterialSpot(3228).JPG to 224x224
#     Resized and saved: BacterialSpot(2955).JPG to 224x224
#     Resized and saved: BacterialSpot(2489).jpg to 224x224
#     Resized and saved: BacterialSpot(2072).jpg to 224x224
#     Resized and saved: BacterialSpot(2054).JPG to 224x224
#     Resized and saved: BacterialSpot(1281).JPG to 224x224
#     Resized and saved: BacterialSpot(1932).jpg to 224x224
#     Resized and saved: BacterialSpot(1869).jpg to 224x224
#     Resized and saved: BacterialSpot(1097).JPG to 224x224
#     Resized and saved: BacterialSpot(1403).jpg to 224x224
#     Resized and saved: BacterialSpot(2956).JPG to 224x224
#     Resized and saved: BacterialSpot(383).JPG to 224x224
#     Resized and saved: BacterialSpot(1181).JPG to 224x224
#     Resized and saved: BacterialSpot(3050).JPG to 224x224
#     Resized and saved: BacterialSpot(2737).JPG to 224x224
#     Resized and saved: BacterialSpot(3012).JPG to 224x224
#     Resized and saved: BacterialSpot(3520).JPG to 224x224
#     Resized and saved: BacterialSpot(464).JPG to 224x224
#     Resized and saved: BacterialSpot(3185).JPG to 224x224
#     Resized and saved: BacterialSpot(2958).JPG to 224x224
#     Resized and saved: BacterialSpot(1968).jpg to 224x224
#     Resized and saved: BacterialSpot(161).JPG to 224x224
#     Resized and saved: BacterialSpot(2414).JPG to 224x224
#     Resized and saved: BacterialSpot(48).JPG to 224x224
#     Resized and saved: BacterialSpot(652).JPG to 224x224
#     Resized and saved: BacterialSpot(3020).JPG to 224x224
#     Resized and saved: BacterialSpot(1987).jpg to 224x224
#     Resized and saved: BacterialSpot(2032).jpg to 224x224
#     Resized and saved: BacterialSpot(1770).jpg to 224x224
#     Resized and saved: BacterialSpot(573).JPG to 224x224
#     Resized and saved: BacterialSpot(844).JPG to 224x224
#     Resized and saved: BacterialSpot(1907).jpg to 224x224
#     Resized and saved: BacterialSpot(996).JPG to 224x224
#     Resized and saved: BacterialSpot(1119).JPG to 224x224
#     Resized and saved: BacterialSpot(3513).JPG to 224x224
#     Resized and saved: BacterialSpot(2308).jpg to 224x224
#     Resized and saved: BacterialSpot(3071).JPG to 224x224
#     Resized and saved: BacterialSpot(1911).jpg to 224x224
#     Resized and saved: BacterialSpot(2231).jpg to 224x224
#     Resized and saved: BacterialSpot(2557).jpg to 224x224
#     Resized and saved: BacterialSpot(398).jpg to 224x224
#     Resized and saved: BacterialSpot(1448).jpg to 224x224
#     Resized and saved: BacterialSpot(104).JPG to 224x224
#     Resized and saved: BacterialSpot(667).JPG to 224x224
#     Resized and saved: BacterialSpot(1166).JPG to 224x224
#     Resized and saved: BacterialSpot(2703).JPG to 224x224
#     Resized and saved: BacterialSpot(1347).jpg to 224x224
#     Resized and saved: BacterialSpot(3101).JPG to 224x224
#     Resized and saved: BacterialSpot(2735).JPG to 224x224
#     Resized and saved: BacterialSpot(3307).JPG to 224x224
#     Resized and saved: BacterialSpot(1951).jpg to 224x224
#     Resized and saved: BacterialSpot(2848).JPG to 224x224
#     Resized and saved: BacterialSpot(3074).JPG to 224x224
#     Resized and saved: BacterialSpot(2177).jpg to 224x224
#     Resized and saved: BacterialSpot(280).JPG to 224x224
#     Resized and saved: BacterialSpot(1684).jpg to 224x224
#     Resized and saved: BacterialSpot(270).JPG to 224x224
#     Resized and saved: BacterialSpot(2081).jpg to 224x224
#     Resized and saved: BacterialSpot(2307).jpg to 224x224
#     Resized and saved: BacterialSpot(1183).JPG to 224x224
#     Resized and saved: BacterialSpot(1074).JPG to 224x224
#     Resized and saved: BacterialSpot(3554).jpg to 224x224
#     Resized and saved: BacterialSpot(1002).JPG to 224x224
#     Resized and saved: BacterialSpot(2699).JPG to 224x224
#     Resized and saved: BacterialSpot(2160).jpg to 224x224
#     Resized and saved: BacterialSpot(1849).jpg to 224x224
#     Resized and saved: BacterialSpot(1527).jpg to 224x224
#     Resized and saved: BacterialSpot(403).JPG to 224x224
#     Resized and saved: BacterialSpot(2724).JPG to 224x224
#     Resized and saved: BacterialSpot(2884).JPG to 224x224
#     Resized and saved: BacterialSpot(920).JPG to 224x224
#     Resized and saved: BacterialSpot(2187).jpg to 224x224
#     Resized and saved: BacterialSpot(730).JPG to 224x224
#     Resized and saved: BacterialSpot(3206).JPG to 224x224
#     Resized and saved: BacterialSpot(3200).JPG to 224x224
#     Resized and saved: BacterialSpot(1882).jpg to 224x224
#     Resized and saved: BacterialSpot(1191).JPG to 224x224
#     Resized and saved: BacterialSpot(450).JPG to 224x224
#     Resized and saved: BacterialSpot(2739).JPG to 224x224
#     Resized and saved: BacterialSpot(2503).jpg to 224x224
#     Resized and saved: BacterialSpot(9).JPG to 224x224
#     Resized and saved: BacterialSpot(2239).jpg to 224x224
#     Resized and saved: BacterialSpot(2863).JPG to 224x224
#     Resized and saved: BacterialSpot(3233).jpg to 224x224
#     Resized and saved: BacterialSpot(2088).jpg to 224x224
#     Resized and saved: BacterialSpot(1965).jpg to 224x224
#     Resized and saved: BacterialSpot(1724).jpg to 224x224
#     Resized and saved: BacterialSpot(1267).JPG to 224x224
#     Resized and saved: BacterialSpot(3503).JPG to 224x224
#     Resized and saved: BacterialSpot(3259).JPG to 224x224
#     Resized and saved: BacterialSpot(1637).jpg to 224x224
#     Resized and saved: BacterialSpot(346).JPG to 224x224
#     Resized and saved: BacterialSpot(2522).jpg to 224x224
#     Resized and saved: BacterialSpot(973).JPG to 224x224
#     Resized and saved: BacterialSpot(2992).JPG to 224x224
#     Resized and saved: BacterialSpot(91).JPG to 224x224
#     Resized and saved: BacterialSpot(743).JPG to 224x224
#     Resized and saved: BacterialSpot(1056).JPG to 224x224
#     Resized and saved: BacterialSpot(166).jpg to 224x224
#     Resized and saved: BacterialSpot(2865).JPG to 224x224
#     Resized and saved: BacterialSpot(1405).jpg to 224x224
#     Resized and saved: BacterialSpot(1362).jpg to 224x224
#     Resized and saved: BacterialSpot(2249).jpg to 224x224
#     Resized and saved: BacterialSpot(1848).jpg to 224x224
#     Resized and saved: BacterialSpot(1503).jpg to 224x224
#     Resized and saved: BacterialSpot(72).JPG to 224x224
#     Resized and saved: BacterialSpot(3359).JPG to 224x224
#     Resized and saved: BacterialSpot(847).JPG to 224x224
#     Resized and saved: BacterialSpot(446).JPG to 224x224
#     Resized and saved: BacterialSpot(1539).jpg to 224x224
#     Resized and saved: BacterialSpot(147).JPG to 224x224
#     Resized and saved: BacterialSpot(1271).JPG to 224x224
#     Resized and saved: BacterialSpot(1239).JPG to 224x224
#     Resized and saved: BacterialSpot(2845).JPG to 224x224
#     Resized and saved: BacterialSpot(2422).jpg to 224x224
#     Resized and saved: BacterialSpot(1885).jpg to 224x224
#     Resized and saved: BacterialSpot(3230).JPG to 224x224
#     Resized and saved: BacterialSpot(3507).JPG to 224x224
#     Resized and saved: BacterialSpot(523).JPG to 224x224
#     Resized and saved: BacterialSpot(859).JPG to 224x224
#     Resized and saved: BacterialSpot(725).JPG to 224x224
#     Resized and saved: BacterialSpot(22).JPG to 224x224
#     Resized and saved: BacterialSpot(3505).JPG to 224x224
#     Resized and saved: BacterialSpot(949).JPG to 224x224
#     Resized and saved: BacterialSpot(968).JPG to 224x224
#     Resized and saved: BacterialSpot(2203).jpg to 224x224
#     Resized and saved: BacterialSpot(888).JPG to 224x224
#     Resized and saved: BacterialSpot(3345).JPG to 224x224
#     Resized and saved: BacterialSpot(892).JPG to 224x224
#     Resized and saved: BacterialSpot(1299).JPG to 224x224
#     Resized and saved: BacterialSpot(3084).JPG to 224x224
#     Resized and saved: BacterialSpot(1730).jpg to 224x224
#     Resized and saved: BacterialSpot(1585).jpg to 224x224
#     Resized and saved: BacterialSpot(2811).JPG to 224x224
#     Resized and saved: BacterialSpot(589).JPG to 224x224
#     Resized and saved: BacterialSpot(1729).jpg to 224x224
#     Resized and saved: BacterialSpot(633).JPG to 224x224
#     Resized and saved: BacterialSpot(1512).jpg to 224x224
#     Resized and saved: BacterialSpot(1341).jpg to 224x224
#     Resized and saved: BacterialSpot(2363).jpg to 224x224
#     Resized and saved: BacterialSpot(1563).jpg to 224x224
#     Resized and saved: BacterialSpot(3338).JPG to 224x224
#     Resized and saved: BacterialSpot(932).JPG to 224x224
#     Resized and saved: BacterialSpot(2168).jpg to 224x224
#     Resized and saved: BacterialSpot(1950).JPG to 224x224
#     Resized and saved: BacterialSpot(1765).jpg to 224x224
#     Resized and saved: BacterialSpot(2108).jpg to 224x224
#     Resized and saved: BacterialSpot(1257).JPG to 224x224
#     Resized and saved: BacterialSpot(87).JPG to 224x224
#     Resized and saved: BacterialSpot(162).JPG to 224x224
#     Resized and saved: BacterialSpot(361).JPG to 224x224
#     Resized and saved: BacterialSpot(3543).jpg to 224x224
#     Resized and saved: BacterialSpot(724).JPG to 224x224
#     Resized and saved: BacterialSpot(372).JPG to 224x224
#     Resized and saved: BacterialSpot(2047).jpg to 224x224
#     Resized and saved: BacterialSpot(1210).JPG to 224x224
#     Resized and saved: BacterialSpot(1177).JPG to 224x224
#     Resized and saved: BacterialSpot(3122).JPG to 224x224
#     Resized and saved: BacterialSpot(971).JPG to 224x224
#     Resized and saved: BacterialSpot(599).JPG to 224x224
#     Resized and saved: BacterialSpot(1649).jpg to 224x224
#     Resized and saved: BacterialSpot(2490).jpg to 224x224
#     Resized and saved: BacterialSpot(23).JPG to 224x224
#     Resized and saved: BacterialSpot(1548).jpg to 224x224
#     Resized and saved: BacterialSpot(1931).jpg to 224x224
#     Resized and saved: BacterialSpot(2313).jpg to 224x224
#     Resized and saved: BacterialSpot(829).JPG to 224x224
#     Resized and saved: BacterialSpot(322).JPG to 224x224
#     Resized and saved: BacterialSpot(7).JPG to 224x224
#     Resized and saved: BacterialSpot(2556).jpg to 224x224
#     Resized and saved: BacterialSpot(1381).jpg to 224x224
#     Resized and saved: BacterialSpot(2943).JPG to 224x224
#     Resized and saved: BacterialSpot(1497).jpg to 224x224
#     Resized and saved: BacterialSpot(2818).JPG to 224x224
#     Resized and saved: BacterialSpot(3136).JPG to 224x224
#     Resized and saved: BacterialSpot(709).JPG to 224x224
#     Resized and saved: BacterialSpot(3234).jpg to 224x224
#     Resized and saved: BacterialSpot(1023).JPG to 224x224
#     Resized and saved: BacterialSpot(886).JPG to 224x224
#     Resized and saved: BacterialSpot(2427).jpg to 224x224
#     Resized and saved: BacterialSpot(3015).JPG to 224x224
#     Resized and saved: BacterialSpot(3299).JPG to 224x224
#     Resized and saved: BacterialSpot(2058).jpg to 224x224
#     Resized and saved: BacterialSpot(1788).jpg to 224x224
#     Resized and saved: BacterialSpot(2452).jpg to 224x224
#     Resized and saved: BacterialSpot(3336).JPG to 224x224
#     Resized and saved: BacterialSpot(2948).JPG to 224x224
#     Resized and saved: BacterialSpot(3509).JPG to 224x224
#     Resized and saved: BacterialSpot(3139).JPG to 224x224
#     Resized and saved: BacterialSpot(855).JPG to 224x224
#     Resized and saved: BacterialSpot(1317).jpg to 224x224
#     Resized and saved: BacterialSpot(2204).jpg to 224x224
#     Resized and saved: BacterialSpot(1086).JPG to 224x224
#     Resized and saved: BacterialSpot(2880).JPG to 224x224
#     Resized and saved: BacterialSpot(1589).jpg to 224x224
#     Resized and saved: BacterialSpot(601).JPG to 224x224
#     Resized and saved: BacterialSpot(758).JPG to 224x224
#     Resized and saved: BacterialSpot(2020).jpg to 224x224
#     Resized and saved: BacterialSpot(129).JPG to 224x224
#     Resized and saved: BacterialSpot(2732).JPG to 224x224
#     Resized and saved: BacterialSpot(1242).JPG to 224x224
#     Resized and saved: BacterialSpot(2388).jpg to 224x224
#     Resized and saved: BacterialSpot(1189).JPG to 224x224
#     Resized and saved: BacterialSpot(1528).jpg to 224x224
#     Resized and saved: BacterialSpot(1201).JPG to 224x224
#     Resized and saved: BacterialSpot(3272).JPG to 224x224
#     Resized and saved: BacterialSpot(320).JPG to 224x224
#     Resized and saved: BacterialSpot(2829).JPG to 224x224
#     Resized and saved: BacterialSpot(2746).JPG to 224x224
#     Resized and saved: BacterialSpot(500).JPG to 224x224
#     Resized and saved: BacterialSpot(1358).jpg to 224x224
#     Resized and saved: BacterialSpot(2264).jpg to 224x224
#     Resized and saved: BacterialSpot(2276).jpg to 224x224
#     Resized and saved: BacterialSpot(745).JPG to 224x224
#     Resized and saved: BacterialSpot(2610).jpg to 224x224
#     Resized and saved: BacterialSpot(2840).jpg to 224x224
#     Resized and saved: BacterialSpot(3498).JPG to 224x224
#     Resized and saved: BacterialSpot(2030).JPG to 224x224
#     Resized and saved: BacterialSpot(1972).jpg to 224x224
#     Resized and saved: BacterialSpot(1903).jpg to 224x224
#     Resized and saved: BacterialSpot(370).JPG to 224x224
#     Resized and saved: BacterialSpot(411).JPG to 224x224
#     Resized and saved: BacterialSpot(2152).jpg to 224x224
#     Resized and saved: BacterialSpot(1260).JPG to 224x224
#     Resized and saved: BacterialSpot(145).JPG to 224x224
#     Resized and saved: BacterialSpot(1898).jpg to 224x224
#     Resized and saved: BacterialSpot(864).JPG to 224x224
#     Resized and saved: BacterialSpot(407).JPG to 224x224
#     Resized and saved: BacterialSpot(309).JPG to 224x224
#     Resized and saved: BacterialSpot(2486).JPG to 224x224
#     Resized and saved: BacterialSpot(2743).JPG to 224x224
#     Resized and saved: BacterialSpot(655).JPG to 224x224
#     Resized and saved: BacterialSpot(207).JPG to 224x224
#     Resized and saved: BacterialSpot(883).JPG to 224x224
#     Resized and saved: BacterialSpot(3488).JPG to 224x224
#     Resized and saved: BacterialSpot(1319).jpg to 224x224
#     Resized and saved: BacterialSpot(2298).jpg to 224x224
#     Resized and saved: BacterialSpot(2107).jpg to 224x224
#     Resized and saved: BacterialSpot(2868).JPG to 224x224
#     Resized and saved: BacterialSpot(1354).jpg to 224x224
#     Resized and saved: BacterialSpot(393).JPG to 224x224
#     Resized and saved: BacterialSpot(1454).jpg to 224x224
#     Resized and saved: BacterialSpot(103).JPG to 224x224
#     Resized and saved: BacterialSpot(1147).JPG to 224x224
#     Resized and saved: BacterialSpot(3125).JPG to 224x224
#     Resized and saved: BacterialSpot(1379).jpg to 224x224
#     Resized and saved: BacterialSpot(2778).JPG to 224x224
#     Resized and saved: BacterialSpot(1416).jpg to 224x224
#     Resized and saved: BacterialSpot(3191).JPG to 224x224
#     Resized and saved: BacterialSpot(183).JPG to 224x224
#     Resized and saved: BacterialSpot(925).JPG to 224x224
#     Resized and saved: BacterialSpot(2542).JPG to 224x224
#     Resized and saved: BacterialSpot(3011).JPG to 224x224
#     Resized and saved: BacterialSpot(3262).JPG to 224x224
#     Resized and saved: BacterialSpot(639).JPG to 224x224
#     Resized and saved: BacterialSpot(727).JPG to 224x224
#     Resized and saved: BacterialSpot(3049).JPG to 224x224
#     Resized and saved: BacterialSpot(3097).JPG to 224x224
#     Resized and saved: BacterialSpot(2434).jpg to 224x224
#     Resized and saved: BacterialSpot(2223).jpg to 224x224
#     Resized and saved: BacterialSpot(1122).JPG to 224x224
#     Resized and saved: BacterialSpot(3224).JPG to 224x224
#     Resized and saved: BacterialSpot(533).JPG to 224x224
#     Resized and saved: BacterialSpot(1104).JPG to 224x224
#     Resized and saved: BacterialSpot(181).JPG to 224x224
#     Resized and saved: BacterialSpot(204).JPG to 224x224
#     Resized and saved: BacterialSpot(2321).jpg to 224x224
#     Resized and saved: BacterialSpot(2819).JPG to 224x224
#     Resized and saved: BacterialSpot(868).JPG to 224x224
#     Resized and saved: BacterialSpot(1089).JPG to 224x224
#     Resized and saved: BacterialSpot(2808).JPG to 224x224
#     Resized and saved: BacterialSpot(2669).JPG to 224x224
#     Resized and saved: BacterialSpot(748).JPG to 224x224
#     Resized and saved: BacterialSpot(522).JPG to 224x224
#     Resized and saved: BacterialSpot(108).JPG to 224x224
#     Resized and saved: BacterialSpot(1126).JPG to 224x224
#     Resized and saved: BacterialSpot(474).JPG to 224x224
#     Resized and saved: BacterialSpot(1819).jpg to 224x224
#     Resized and saved: BacterialSpot(444).JPG to 224x224
#     Resized and saved: BacterialSpot(2872).JPG to 224x224
#     Resized and saved: BacterialSpot(946).JPG to 224x224
#     Resized and saved: BacterialSpot(2242).jpg to 224x224
#     Resized and saved: BacterialSpot(1559).jpg to 224x224
#     Resized and saved: BacterialSpot(2850).JPG to 224x224
#     Resized and saved: BacterialSpot(2420).jpg to 224x224
#     Resized and saved: BacterialSpot(2655).JPG to 224x224
#     Resized and saved: BacterialSpot(1534).jpg to 224x224
#     Resized and saved: BacterialSpot(2).JPG to 224x224
#     Resized and saved: BacterialSpot(1506).jpg to 224x224
#     Resized and saved: BacterialSpot(2874).JPG to 224x224
#     Resized and saved: BacterialSpot(2954).JPG to 224x224
#     Resized and saved: BacterialSpot(611).JPG to 224x224
#     Resized and saved: BacterialSpot(701).JPG to 224x224
#     Resized and saved: BacterialSpot(436).JPG to 224x224
#     Resized and saved: BacterialSpot(3323).JPG to 224x224
#     Resized and saved: BacterialSpot(2317).jpg to 224x224
#     Resized and saved: BacterialSpot(2529).jpg to 224x224
#     Resized and saved: BacterialSpot(2462).JPG to 224x224
#     Resized and saved: BacterialSpot(323).JPG to 224x224
#     Resized and saved: BacterialSpot(2910).jpg to 224x224
#     Resized and saved: BacterialSpot(79).JPG to 224x224
#     Resized and saved: BacterialSpot(1136).JPG to 224x224
#     Resized and saved: BacterialSpot(2594).jpg to 224x224
#     Resized and saved: BacterialSpot(484).JPG to 224x224
#     Resized and saved: BacterialSpot(1876).jpg to 224x224
#     Resized and saved: BacterialSpot(3247).JPG to 224x224
#     Resized and saved: BacterialSpot(547).JPG to 224x224
#     Resized and saved: BacterialSpot(296).JPG to 224x224
#     Resized and saved: BacterialSpot(257).JPG to 224x224
#     Resized and saved: BacterialSpot(274).JPG to 224x224
#     Resized and saved: BacterialSpot(2770).JPG to 224x224
#     Resized and saved: BacterialSpot(179).JPG to 224x224
#     Resized and saved: BacterialSpot(3065).JPG to 224x224
#     Resized and saved: BacterialSpot(2194).jpg to 224x224
#     Resized and saved: BacterialSpot(112).JPG to 224x224
#     Resized and saved: BacterialSpot(2473).jpg to 224x224
#     Resized and saved: BacterialSpot(715).JPG to 224x224
#     Resized and saved: BacterialSpot(1904).jpg to 224x224
#     Resized and saved: BacterialSpot(389).JPG to 224x224
#     Resized and saved: BacterialSpot(2325).jpg to 224x224
#     Resized and saved: BacterialSpot(1411).jpg to 224x224
#     Resized and saved: BacterialSpot(70).JPG to 224x224
#     Resized and saved: BacterialSpot(2470).JPG to 224x224
#     Resized and saved: BacterialSpot(2328).jpg to 224x224
#     Resized and saved: BacterialSpot(2013).jpg to 224x224
#     Resized and saved: BacterialSpot(2247).jpg to 224x224
#     Resized and saved: BacterialSpot(615).JPG to 224x224
#     Resized and saved: BacterialSpot(815).JPG to 224x224
#     Resized and saved: BacterialSpot(3312).JPG to 224x224
#     Resized and saved: BacterialSpot(3124).JPG to 224x224
#     Resized and saved: BacterialSpot(629).JPG to 224x224
#     Resized and saved: BacterialSpot(2804).JPG to 224x224
#     Resized and saved: BacterialSpot(2372).jpg to 224x224
#     Resized and saved: BacterialSpot(513).JPG to 224x224
#     Resized and saved: BacterialSpot(2772).JPG to 224x224
#     Resized and saved: BacterialSpot(3401).JPG to 224x224
#     Resized and saved: BacterialSpot(3311).JPG to 224x224
#     Resized and saved: BacterialSpot(2314).jpg to 224x224
#     Resized and saved: BacterialSpot(3159).JPG to 224x224
#     Resized and saved: BacterialSpot(2064).jpg to 224x224
#     Resized and saved: BacterialSpot(1474).jpg to 224x224
#     Resized and saved: BacterialSpot(3208).JPG to 224x224
#     Resized and saved: BacterialSpot(2297).jpg to 224x224
#     Resized and saved: BacterialSpot(397).jpg to 224x224
#     Resized and saved: BacterialSpot(3339).JPG to 224x224
#     Resized and saved: BacterialSpot(2419).jpg to 224x224
#     Resized and saved: BacterialSpot(2441).jpg to 224x224
#     Resized and saved: BacterialSpot(328).JPG to 224x224
#     Resized and saved: BacterialSpot(566).JPG to 224x224
#     Resized and saved: BacterialSpot(1578).jpg to 224x224
#     Resized and saved: BacterialSpot(2502).JPG to 224x224
#     Resized and saved: BacterialSpot(101).JPG to 224x224
#     Resized and saved: BacterialSpot(952).JPG to 224x224
#     Resized and saved: BacterialSpot(905).JPG to 224x224
#     Resized and saved: BacterialSpot(2813).JPG to 224x224
#     Resized and saved: BacterialSpot(419).JPG to 224x224
#     Resized and saved: BacterialSpot(799).JPG to 224x224
#     Resized and saved: BacterialSpot(2894).jpg to 224x224
#     Resized and saved: BacterialSpot(2395).jpg to 224x224
#     Resized and saved: BacterialSpot(2822).JPG to 224x224
#     Resized and saved: BacterialSpot(3487).JPG to 224x224
#     Resized and saved: BacterialSpot(752).JPG to 224x224
#     Resized and saved: BacterialSpot(1949).jpg to 224x224
#     Resized and saved: BacterialSpot(2358).JPG to 224x224
#     Resized and saved: BacterialSpot(1443).jpg to 224x224
#     Resized and saved: BacterialSpot(622).JPG to 224x224
#     Resized and saved: BacterialSpot(2563).jpg to 224x224
#     Resized and saved: BacterialSpot(2663).JPG to 224x224
#     Resized and saved: BacterialSpot(1151).JPG to 224x224
#     Resized and saved: BacterialSpot(2059).jpg to 224x224
#     Resized and saved: BacterialSpot(2709).JPG to 224x224
#     Resized and saved: BacterialSpot(2714).JPG to 224x224
#     Resized and saved: BacterialSpot(1092).JPG to 224x224
#     Resized and saved: BacterialSpot(717).JPG to 224x224
#     Resized and saved: BacterialSpot(1082).JPG to 224x224
#     Resized and saved: BacterialSpot(3382).JPG to 224x224
#     Resized and saved: BacterialSpot(1614).jpg to 224x224
#     Resized and saved: BacterialSpot(233).JPG to 224x224
#     Resized and saved: BacterialSpot(3231).JPG to 224x224
#     Resized and saved: BacterialSpot(3104).JPG to 224x224
#     Resized and saved: BacterialSpot(135).JPG to 224x224
#     Resized and saved: BacterialSpot(213).JPG to 224x224
#     Resized and saved: BacterialSpot(2139).jpg to 224x224
#     Resized and saved: BacterialSpot(1516).jpg to 224x224
#     Resized and saved: BacterialSpot(2799).JPG to 224x224
#     Resized and saved: BacterialSpot(2707).JPG to 224x224
#     Resized and saved: BacterialSpot(2153).jpg to 224x224
#     Resized and saved: BacterialSpot(3148).JPG to 224x224
#     Resized and saved: BacterialSpot(2658).JPG to 224x224
#     Resized and saved: BacterialSpot(3030).JPG to 224x224
#     Resized and saved: BacterialSpot(2019).jpg to 224x224
#     Resized and saved: BacterialSpot(1722).jpg to 224x224
#     Resized and saved: BacterialSpot(1866).jpg to 224x224
#     Resized and saved: BacterialSpot(2065).jpg to 224x224
#     Resized and saved: BacterialSpot(3147).JPG to 224x224
#     Resized and saved: BacterialSpot(736).JPG to 224x224
#     Resized and saved: BacterialSpot(1302).JPG to 224x224
#     Resized and saved: BacterialSpot(423).JPG to 224x224
#     Resized and saved: BacterialSpot(2700).JPG to 224x224
#     Resized and saved: BacterialSpot(2236).jpg to 224x224
#     Resized and saved: BacterialSpot(367).JPG to 224x224
#     Resized and saved: BacterialSpot(3203).JPG to 224x224
#     Resized and saved: BacterialSpot(1731).jpg to 224x224
#     Resized and saved: BacterialSpot(591).JPG to 224x224
#     Resized and saved: BacterialSpot(2480).jpg to 224x224
#     Resized and saved: BacterialSpot(812).JPG to 224x224
#     Resized and saved: BacterialSpot(410).JPG to 224x224
#     Resized and saved: BacterialSpot(1560).jpg to 224x224
#     Resized and saved: BacterialSpot(1717).jpg to 224x224
#     Resized and saved: BacterialSpot(1697).jpg to 224x224
#     Resized and saved: BacterialSpot(2424).jpg to 224x224
#     Resized and saved: BacterialSpot(1786).jpg to 224x224
#     Resized and saved: BacterialSpot(243).JPG to 224x224
#     Resized and saved: BacterialSpot(496).JPG to 224x224
#     Resized and saved: BacterialSpot(2066).jpg to 224x224
#     Resized and saved: BacterialSpot(2099).jpg to 224x224
#     Resized and saved: BacterialSpot(1916).jpg to 224x224
#     Resized and saved: BacterialSpot(1628).jpg to 224x224
#     Resized and saved: BacterialSpot(1342).jpg to 224x224
#     Resized and saved: BacterialSpot(1660).jpg to 224x224
#     Resized and saved: BacterialSpot(1647).jpg to 224x224
#     Resized and saved: BacterialSpot(3425).JPG to 224x224
#     Resized and saved: BacterialSpot(3271).JPG to 224x224
#     Resized and saved: BacterialSpot(369).JPG to 224x224
#     Resized and saved: BacterialSpot(3284).JPG to 224x224
#     Resized and saved: BacterialSpot(2227).jpg to 224x224
#     Resized and saved: BacterialSpot(1450).jpg to 224x224
#     Resized and saved: BacterialSpot(682).JPG to 224x224
#     Resized and saved: BacterialSpot(65).JPG to 224x224
#     Resized and saved: BacterialSpot(2527).jpg to 224x224
#     Resized and saved: BacterialSpot(2278).JPG to 224x224
#     Resized and saved: BacterialSpot(2756).JPG to 224x224
#     Resized and saved: BacterialSpot(3529).JPG to 224x224
#     Resized and saved: BacterialSpot(828).JPG to 224x224
#     Resized and saved: BacterialSpot(1604).jpg to 224x224
#     Resized and saved: BacterialSpot(2640).jpg to 224x224
#     Resized and saved: BacterialSpot(1531).jpg to 224x224
#     Resized and saved: BacterialSpot(349).JPG to 224x224
#     Resized and saved: BacterialSpot(1101).JPG to 224x224
#     Resized and saved: BacterialSpot(1518).jpg to 224x224
#     Resized and saved: BacterialSpot(2000).jpg to 224x224
#     Resized and saved: BacterialSpot(1955).jpg to 224x224
#     Resized and saved: BacterialSpot(3418).JPG to 224x224
#     Resized and saved: BacterialSpot(984).JPG to 224x224
#     Resized and saved: BacterialSpot(3246).JPG to 224x224
#     Resized and saved: BacterialSpot(2939).JPG to 224x224
#     Resized and saved: BacterialSpot(2150).JPG to 224x224
#     Resized and saved: BacterialSpot(3324).JPG to 224x224
#     Resized and saved: BacterialSpot(1979).jpg to 224x224
#     Resized and saved: BacterialSpot(1111).JPG to 224x224
#     Resized and saved: BacterialSpot(1893).jpg to 224x224
#     Resized and saved: BacterialSpot(1402).jpg to 224x224
#     Resized and saved: BacterialSpot(1946).jpg to 224x224
#     Resized and saved: BacterialSpot(3518).JPG to 224x224
#     Resized and saved: BacterialSpot(405).JPG to 224x224
#     Resized and saved: BacterialSpot(1925).jpg to 224x224
#     Resized and saved: BacterialSpot(1993).jpg to 224x224
#     Resized and saved: BacterialSpot(3260).JPG to 224x224
#     Resized and saved: BacterialSpot(3131).JPG to 224x224
#     Resized and saved: BacterialSpot(1371).jpg to 224x224
#     Resized and saved: BacterialSpot(1167).JPG to 224x224
#     Resized and saved: BacterialSpot(2029).jpg to 224x224
#     Resized and saved: BacterialSpot(1762).jpg to 224x224
#     Resized and saved: BacterialSpot(2410).jpg to 224x224
#     Resized and saved: BacterialSpot(1061).JPG to 224x224
#     Resized and saved: BacterialSpot(2587).jpg to 224x224
#     Resized and saved: BacterialSpot(3237).JPG to 224x224
#     Resized and saved: BacterialSpot(688).JPG to 224x224
#     Resized and saved: BacterialSpot(1606).jpg to 224x224
#     Resized and saved: BacterialSpot(805).JPG to 224x224
#     Resized and saved: BacterialSpot(2891).jpg to 224x224
#     Resized and saved: BacterialSpot(3181).JPG to 224x224
#     Resized and saved: BacterialSpot(697).JPG to 224x224
#     Resized and saved: BacterialSpot(371).JPG to 224x224
#     Resized and saved: BacterialSpot(2607).jpg to 224x224
#     Resized and saved: BacterialSpot(1157).JPG to 224x224
#     Resized and saved: BacterialSpot(2383).jpg to 224x224
#     Resized and saved: BacterialSpot(2373).jpg to 224x224
#     Resized and saved: BacterialSpot(1652).jpg to 224x224
#     Resized and saved: BacterialSpot(116).JPG to 224x224
#     Resized and saved: BacterialSpot(898).JPG to 224x224
#     Resized and saved: BacterialSpot(2466).jpg to 224x224
#     Resized and saved: BacterialSpot(2070).jpg to 224x224
#     Resized and saved: BacterialSpot(3048).JPG to 224x224
#     Resized and saved: BacterialSpot(2258).jpg to 224x224
#     Resized and saved: BacterialSpot(718).JPG to 224x224
#     Resized and saved: BacterialSpot(492).JPG to 224x224
#     Resized and saved: BacterialSpot(1351).jpg to 224x224
#     Resized and saved: BacterialSpot(416).JPG to 224x224
#     Resized and saved: BacterialSpot(974).JPG to 224x224
#     Resized and saved: BacterialSpot(1471).jpg to 224x224
#     Resized and saved: BacterialSpot(1806).jpg to 224x224
#     Resized and saved: BacterialSpot(650).JPG to 224x224
#     Resized and saved: BacterialSpot(517).JPG to 224x224
#     Resized and saved: BacterialSpot(1610).jpg to 224x224
#     Resized and saved: BacterialSpot(1214).JPG to 224x224
#     Resized and saved: BacterialSpot(3525).JPG to 224x224
#     Resized and saved: BacterialSpot(1517).jpg to 224x224
#     Resized and saved: BacterialSpot(100).JPG to 224x224
#     Resized and saved: BacterialSpot(2635).jpg to 224x224
#     Resized and saved: BacterialSpot(1771).jpg to 224x224
#     Resized and saved: BacterialSpot(172).JPG to 224x224
#     Resized and saved: BacterialSpot(168).JPG to 224x224
#     Resized and saved: BacterialSpot(1641).jpg to 224x224
#     Resized and saved: BacterialSpot(1484).jpg to 224x224
#     Resized and saved: BacterialSpot(1066).JPG to 224x224
#     Resized and saved: BacterialSpot(1570).jpg to 224x224
#     Resized and saved: BacterialSpot(2408).jpg to 224x224
#     Resized and saved: BacterialSpot(1769).jpg to 224x224
#     Resized and saved: BacterialSpot(1839).jpg to 224x224
#     Resized and saved: BacterialSpot(1062).JPG to 224x224
#     Resized and saved: BacterialSpot(3116).JPG to 224x224
#     Resized and saved: BacterialSpot(94).JPG to 224x224
#     Resized and saved: BacterialSpot(3502).JPG to 224x224
#     Resized and saved: BacterialSpot(2345).jpg to 224x224
#     Resized and saved: BacterialSpot(3129).JPG to 224x224
#     Resized and saved: BacterialSpot(2374).JPG to 224x224
#     Resized and saved: BacterialSpot(10).JPG to 224x224
#     Resized and saved: BacterialSpot(1857).jpg to 224x224
#     Resized and saved: BacterialSpot(638).JPG to 224x224
#     Resized and saved: BacterialSpot(2025).jpg to 224x224
#     Resized and saved: BacterialSpot(281).JPG to 224x224
#     Resized and saved: BacterialSpot(2937).JPG to 224x224
#     Resized and saved: BacterialSpot(856).JPG to 224x224
#     Resized and saved: BacterialSpot(613).JPG to 224x224
#     Resized and saved: BacterialSpot(818).JPG to 224x224
#     Resized and saved: BacterialSpot(345).JPG to 224x224
#     Resized and saved: BacterialSpot(1943).jpg to 224x224
#     Resized and saved: BacterialSpot(2012).jpg to 224x224
#     Resized and saved: BacterialSpot(891).JPG to 224x224
#     Resized and saved: BacterialSpot(1186).JPG to 224x224
#     Resized and saved: BacterialSpot(2698).JPG to 224x224
#     Resized and saved: BacterialSpot(2985).JPG to 224x224
#     Resized and saved: BacterialSpot(2913).jpg to 224x224
#     Resized and saved: BacterialSpot(3340).JPG to 224x224
#     Resized and saved: BacterialSpot(3039).JPG to 224x224
#     Resized and saved: BacterialSpot(1410).jpg to 224x224
#     Resized and saved: BacterialSpot(2938).JPG to 224x224
#     Resized and saved: BacterialSpot(2749).JPG to 224x224
#     Resized and saved: BacterialSpot(3254).JPG to 224x224
#     Resized and saved: BacterialSpot(1969).jpg to 224x224
#     Resized and saved: BacterialSpot(2393).jpg to 224x224
#     Resized and saved: BacterialSpot(700).JPG to 224x224
#     Resized and saved: BacterialSpot(2836).JPG to 224x224
#     Resized and saved: BacterialSpot(1108).JPG to 224x224
#     Resized and saved: BacterialSpot(1953).jpg to 224x224
#     Resized and saved: BacterialSpot(330).JPG to 224x224
#     Resized and saved: BacterialSpot(1996).jpg to 224x224
#     Resized and saved: BacterialSpot(1726).JPG to 224x224
#     Resized and saved: BacterialSpot(2429).JPG to 224x224
#     Resized and saved: BacterialSpot(1961).jpg to 224x224
#     Resized and saved: BacterialSpot(430).JPG to 224x224
#     Resized and saved: BacterialSpot(1510).jpg to 224x224
#     Resized and saved: BacterialSpot(797).JPG to 224x224
#     Resized and saved: BacterialSpot(1026).JPG to 224x224
#     Resized and saved: BacterialSpot(153).JPG to 224x224
#     Resized and saved: BacterialSpot(1075).JPG to 224x224
#     Resized and saved: BacterialSpot(2720).JPG to 224x224
#     Resized and saved: BacterialSpot(315).JPG to 224x224
#     Resized and saved: BacterialSpot(1825).jpg to 224x224
#     Resized and saved: BacterialSpot(2903).jpg to 224x224
#     Resized and saved: BacterialSpot(1019).JPG to 224x224
#     Resized and saved: BacterialSpot(26).JPG to 224x224
#     Resized and saved: BacterialSpot(3435).JPG to 224x224
#     Resized and saved: BacterialSpot(1099).JPG to 224x224
#     Resized and saved: BacterialSpot(982).JPG to 224x224
#     Resized and saved: BacterialSpot(3190).JPG to 224x224
#     Resized and saved: BacterialSpot(1100).JPG to 224x224
#     Resized and saved: BacterialSpot(1429).jpg to 224x224
#     Resized and saved: BacterialSpot(2895).jpg to 224x224
#     Resized and saved: BacterialSpot(2413).jpg to 224x224
#     Resized and saved: BacterialSpot(950).JPG to 224x224
#     Resized and saved: BacterialSpot(1182).JPG to 224x224
#     Resized and saved: BacterialSpot(427).JPG to 224x224
#     Resized and saved: BacterialSpot(85).JPG to 224x224
#     Resized and saved: BacterialSpot(3464).JPG to 224x224
#     Resized and saved: BacterialSpot(1297).JPG to 224x224
#     Resized and saved: BacterialSpot(1752).jpg to 224x224
#     Resized and saved: BacterialSpot(2342).JPG to 224x224
#     Resized and saved: BacterialSpot(3453).JPG to 224x224
#     Resized and saved: BacterialSpot(1909).jpg to 224x224
#     Resized and saved: BacterialSpot(2436).jpg to 224x224
#     Resized and saved: BacterialSpot(2951).JPG to 224x224
#     Resized and saved: BacterialSpot(714).JPG to 224x224
#     Resized and saved: BacterialSpot(2928).JPG to 224x224
#     Resized and saved: BacterialSpot(1758).jpg to 224x224
#     Resized and saved: BacterialSpot(2366).JPG to 224x224
#     Resized and saved: BacterialSpot(1222).JPG to 224x224
#     Resized and saved: BacterialSpot(2854).JPG to 224x224
#     Resized and saved: BacterialSpot(1176).JPG to 224x224
#     Resized and saved: BacterialSpot(1966).JPG to 224x224
#     Resized and saved: BacterialSpot(773).JPG to 224x224
#     Resized and saved: BacterialSpot(1397).jpg to 224x224
#     Resized and saved: BacterialSpot(3293).JPG to 224x224
#     Resized and saved: BacterialSpot(1837).jpg to 224x224
#     Resized and saved: BacterialSpot(1888).jpg to 224x224
#     Resized and saved: BacterialSpot(687).JPG to 224x224
#     Resized and saved: BacterialSpot(138).JPG to 224x224
#     Resized and saved: BacterialSpot(1509).jpg to 224x224
#     Resized and saved: BacterialSpot(3483).JPG to 224x224
#     Resized and saved: BacterialSpot(919).JPG to 224x224
#     Resized and saved: BacterialSpot(61).JPG to 224x224
#     Resized and saved: BacterialSpot(2174).JPG to 224x224
#     Resized and saved: BacterialSpot(1085).JPG to 224x224
#     Resized and saved: BacterialSpot(2980).JPG to 224x224
#     Resized and saved: BacterialSpot(3538).jpg to 224x224
#     Resized and saved: BacterialSpot(3465).JPG to 224x224
#     Resized and saved: BacterialSpot(1142).JPG to 224x224
#     Resized and saved: BacterialSpot(1248).JPG to 224x224
#     Resized and saved: BacterialSpot(1508).jpg to 224x224
#     Resized and saved: BacterialSpot(1942).JPG to 224x224
#     Resized and saved: BacterialSpot(3225).JPG to 224x224
#     Resized and saved: BacterialSpot(377).JPG to 224x224
#     Resized and saved: BacterialSpot(55).JPG to 224x224
#     Resized and saved: BacterialSpot(1567).jpg to 224x224
#     Resized and saved: BacterialSpot(21).JPG to 224x224
#     Resized and saved: BacterialSpot(2867).JPG to 224x224
#     Resized and saved: BacterialSpot(2571).jpg to 224x224
#     Resized and saved: BacterialSpot(2447).jpg to 224x224
#     Resized and saved: BacterialSpot(3255).JPG to 224x224
#     Resized and saved: BacterialSpot(1791).JPG to 224x224
#     Resized and saved: BacterialSpot(2740).JPG to 224x224
#     Resized and saved: BacterialSpot(67).JPG to 224x224
#     Resized and saved: BacterialSpot(351).JPG to 224x224
#     Resized and saved: BacterialSpot(2455).jpg to 224x224
#     Resized and saved: BacterialSpot(2668).JPG to 224x224
#     Resized and saved: BacterialSpot(2838).jpg to 224x224
#     Resized and saved: BacterialSpot(2320).jpg to 224x224
#     Resized and saved: BacterialSpot(3325).JPG to 224x224
#     Resized and saved: BacterialSpot(1621).jpg to 224x224
#     Resized and saved: BacterialSpot(747).JPG to 224x224
#     Resized and saved: BacterialSpot(1658).jpg to 224x224
#     Resized and saved: BacterialSpot(1853).jpg to 224x224
#     Resized and saved: BacterialSpot(400).JPG to 224x224
#     Resized and saved: BacterialSpot(1597).jpg to 224x224
#     Resized and saved: BacterialSpot(2967).JPG to 224x224
#     Resized and saved: BacterialSpot(1322).jpg to 224x224
#     Resized and saved: BacterialSpot(2211).jpg to 224x224
#     Resized and saved: BacterialSpot(2288).jpg to 224x224
#     Resized and saved: BacterialSpot(1280).JPG to 224x224
#     Resized and saved: BacterialSpot(2167).jpg to 224x224
#     Resized and saved: BacterialSpot(593).JPG to 224x224
#     Resized and saved: BacterialSpot(2409).jpg to 224x224
#     Resized and saved: BacterialSpot(42).JPG to 224x224
#     Resized and saved: BacterialSpot(1282).JPG to 224x224
#     Resized and saved: BacterialSpot(1017).JPG to 224x224
#     Resized and saved: BacterialSpot(2004).jpg to 224x224
#     Resized and saved: BacterialSpot(1150).JPG to 224x224
#     Resized and saved: BacterialSpot(1283).JPG to 224x224
#     Resized and saved: BacterialSpot(1644).jpg to 224x224
#     Resized and saved: BacterialSpot(524).JPG to 224x224
#     Resized and saved: BacterialSpot(1290).JPG to 224x224
#     Resized and saved: BacterialSpot(794).JPG to 224x224
#     Resized and saved: BacterialSpot(3358).JPG to 224x224
#     Resized and saved: BacterialSpot(955).JPG to 224x224
#     Resized and saved: BacterialSpot(3391).JPG to 224x224
#     Resized and saved: BacterialSpot(58).JPG to 224x224
#     Resized and saved: BacterialSpot(1615).jpg to 224x224
#     Resized and saved: BacterialSpot(2633).jpg to 224x224
#     Resized and saved: BacterialSpot(1203).JPG to 224x224
#     Resized and saved: BacterialSpot(1977).jpg to 224x224
#     Resized and saved: BacterialSpot(1677).jpg to 224x224
#     Resized and saved: BacterialSpot(2767).JPG to 224x224
#     Resized and saved: BacterialSpot(678).JPG to 224x224
#     Resized and saved: BacterialSpot(2402).jpg to 224x224
#     Resized and saved: BacterialSpot(1875).jpg to 224x224
#     Resized and saved: BacterialSpot(3295).JPG to 224x224
#     Resized and saved: BacterialSpot(125).JPG to 224x224
#     Resized and saved: BacterialSpot(3080).JPG to 224x224
#     Resized and saved: BacterialSpot(986).JPG to 224x224
#     Resized and saved: BacterialSpot(417).JPG to 224x224
#     Resized and saved: BacterialSpot(756).JPG to 224x224
#     Resized and saved: BacterialSpot(2037).jpg to 224x224
#     Resized and saved: BacterialSpot(2966).JPG to 224x224
#     Resized and saved: BacterialSpot(1612).jpg to 224x224
#     Resized and saved: BacterialSpot(3395).JPG to 224x224
#     Resized and saved: BacterialSpot(3462).JPG to 224x224
#     Resized and saved: BacterialSpot(2544).jpg to 224x224
#     Resized and saved: BacterialSpot(1196).JPG to 224x224
#     Resized and saved: BacterialSpot(1579).jpg to 224x224
#     Resized and saved: BacterialSpot(1556).jpg to 224x224
#     Resized and saved: BacterialSpot(2554).jpg to 224x224
#     Resized and saved: BacterialSpot(2801).JPG to 224x224
#     Resized and saved: BacterialSpot(3036).JPG to 224x224
#     Resized and saved: BacterialSpot(1601).jpg to 224x224
#     Resized and saved: BacterialSpot(2024).jpg to 224x224
#     Resized and saved: BacterialSpot(1890).jpg to 224x224
#     Resized and saved: BacterialSpot(535).JPG to 224x224
#     Resized and saved: BacterialSpot(2559).jpg to 224x224
#     Resized and saved: BacterialSpot(2125).jpg to 224x224
#     Resized and saved: BacterialSpot(1922).jpg to 224x224
#     Resized and saved: BacterialSpot(3086).JPG to 224x224
#     Resized and saved: BacterialSpot(3013).JPG to 224x224
#     Resized and saved: BacterialSpot(2045).jpg to 224x224
#     Resized and saved: BacterialSpot(406).JPG to 224x224
#     Resized and saved: BacterialSpot(2585).jpg to 224x224
#     Resized and saved: BacterialSpot(1192).JPG to 224x224
#     Resized and saved: BacterialSpot(1808).jpg to 224x224
#     Resized and saved: BacterialSpot(1237).JPG to 224x224
#     Resized and saved: BacterialSpot(3167).JPG to 224x224
#     Resized and saved: BacterialSpot(1262).JPG to 224x224
#     Resized and saved: BacterialSpot(2796).jpg to 224x224
#     Resized and saved: BacterialSpot(236).JPG to 224x224
#     Resized and saved: BacterialSpot(2514).jpg to 224x224
#     Resized and saved: BacterialSpot(3075).JPG to 224x224
#     Resized and saved: BacterialSpot(2360).jpg to 224x224
#     Resized and saved: BacterialSpot(3496).JPG to 224x224
#     Resized and saved: BacterialSpot(2978).JPG to 224x224
#     Resized and saved: BacterialSpot(592).JPG to 224x224
#     Resized and saved: BacterialSpot(537).JPG to 224x224
#     Resized and saved: BacterialSpot(2791).JPG to 224x224
#     Resized and saved: BacterialSpot(1984).jpg to 224x224
#     Resized and saved: BacterialSpot(506).JPG to 224x224
#     Resized and saved: BacterialSpot(2773).JPG to 224x224
#     Resized and saved: BacterialSpot(1736).jpg to 224x224
#     Resized and saved: BacterialSpot(1440).jpg to 224x224
#     Resized and saved: BacterialSpot(2397).jpg to 224x224
#     Resized and saved: BacterialSpot(2336).jpg to 224x224
#     Resized and saved: BacterialSpot(2316).jpg to 224x224
#     Resized and saved: BacterialSpot(1748).jpg to 224x224
#     Resized and saved: BacterialSpot(3349).JPG to 224x224
#     Resized and saved: BacterialSpot(2856).JPG to 224x224
#     Resized and saved: BacterialSpot(199).JPG to 224x224
#     Resized and saved: BacterialSpot(2844).JPG to 224x224
#     Resized and saved: BacterialSpot(2259).jpg to 224x224
#     Resized and saved: BacterialSpot(1468).jpg to 224x224
#     Resized and saved: BacterialSpot(2312).jpg to 224x224
#     Resized and saved: BacterialSpot(1792).jpg to 224x224
#     Resized and saved: BacterialSpot(306).JPG to 224x224
#     Resized and saved: BacterialSpot(691).JPG to 224x224
#     Resized and saved: BacterialSpot(2860).JPG to 224x224
#     Resized and saved: BacterialSpot(267).JPG to 224x224
#     Resized and saved: BacterialSpot(744).JPG to 224x224
#     Resized and saved: BacterialSpot(1464).jpg to 224x224
#     Resized and saved: BacterialSpot(3551).jpg to 224x224
#     Resized and saved: BacterialSpot(1348).jpg to 224x224
#     Resized and saved: BacterialSpot(2322).jpg to 224x224
#     Resized and saved: BacterialSpot(2430).JPG to 224x224
#     Resized and saved: BacterialSpot(1400).jpg to 224x224
#     Resized and saved: BacterialSpot(3389).JPG to 224x224
#     Resized and saved: BacterialSpot(3130).JPG to 224x224
#     Resized and saved: BacterialSpot(1143).JPG to 224x224
#     Resized and saved: BacterialSpot(121).JPG to 224x224
#     Resized and saved: BacterialSpot(1452).jpg to 224x224
#     Resized and saved: BacterialSpot(833).JPG to 224x224
#     Resized and saved: BacterialSpot(1957).jpg to 224x224
#     Resized and saved: BacterialSpot(1243).JPG to 224x224
#     Resized and saved: BacterialSpot(2723).JPG to 224x224
#     Resized and saved: BacterialSpot(556).JPG to 224x224
#     Resized and saved: BacterialSpot(412).JPG to 224x224
#     Resized and saved: BacterialSpot(1447).jpg to 224x224
#     Resized and saved: BacterialSpot(1206).JPG to 224x224
#     Resized and saved: BacterialSpot(17).JPG to 224x224
#     Resized and saved: BacterialSpot(1971).jpg to 224x224
#     Resized and saved: BacterialSpot(2678).JPG to 224x224
#     Resized and saved: BacterialSpot(943).JPG to 224x224
#     Resized and saved: BacterialSpot(1831).jpg to 224x224
#     Resized and saved: BacterialSpot(3106).JPG to 224x224
#     Resized and saved: BacterialSpot(1437).jpg to 224x224
#     Resized and saved: BacterialSpot(728).JPG to 224x224
#     Resized and saved: BacterialSpot(1470).jpg to 224x224
#     Resized and saved: BacterialSpot(988).JPG to 224x224
#     Resized and saved: BacterialSpot(28).JPG to 224x224
#     Resized and saved: BacterialSpot(2774).JPG to 224x224
#     Resized and saved: BacterialSpot(1500).jpg to 224x224
#     Resized and saved: BacterialSpot(2148).jpg to 224x224
#     Resized and saved: BacterialSpot(2338).jpg to 224x224
#     Resized and saved: BacterialSpot(874).JPG to 224x224
#     Resized and saved: BacterialSpot(3394).JPG to 224x224
#     Resized and saved: BacterialSpot(867).JPG to 224x224
#     Resized and saved: BacterialSpot(2925).jpg to 224x224
#     Resized and saved: BacterialSpot(2513).jpg to 224x224
#     Resized and saved: BacterialSpot(1446).jpg to 224x224
#     Resized and saved: BacterialSpot(1118).JPG to 224x224
#     Resized and saved: BacterialSpot(3326).JPG to 224x224
#     Resized and saved: BacterialSpot(625).JPG to 224x224
#     Resized and saved: BacterialSpot(2435).jpg to 224x224
#     Resized and saved: BacterialSpot(2797).jpg to 224x224
#     Resized and saved: BacterialSpot(2454).JPG to 224x224
#     Resized and saved: BacterialSpot(1981).jpg to 224x224
#     Resized and saved: BacterialSpot(1318).jpg to 224x224
#     Resized and saved: BacterialSpot(3398).JPG to 224x224
#     Resized and saved: BacterialSpot(2975).JPG to 224x224
#     Resized and saved: BacterialSpot(1459).jpg to 224x224
#     Resized and saved: BacterialSpot(3454).JPG to 224x224
#     Resized and saved: BacterialSpot(1346).jpg to 224x224
#     Resized and saved: BacterialSpot(1733).jpg to 224x224
#     Resized and saved: BacterialSpot(612).JPG to 224x224
#     Resized and saved: BacterialSpot(1275).JPG to 224x224
#     Resized and saved: BacterialSpot(1945).jpg to 224x224
#     Resized and saved: BacterialSpot(3473).JPG to 224x224
#     Resized and saved: BacterialSpot(2300).jpg to 224x224
#     Resized and saved: BacterialSpot(141).JPG to 224x224
#     Resized and saved: BacterialSpot(795).JPG to 224x224
#     Resized and saved: BacterialSpot(137).JPG to 224x224
#     Resized and saved: BacterialSpot(1057).JPG to 224x224
#     Resized and saved: BacterialSpot(66).JPG to 224x224
#     Resized and saved: BacterialSpot(2982).JPG to 224x224
#     Resized and saved: BacterialSpot(1676).jpg to 224x224
#     Resized and saved: BacterialSpot(3438).JPG to 224x224
#     Resized and saved: BacterialSpot(800).JPG to 224x224
#     Resized and saved: BacterialSpot(558).JPG to 224x224
#     Resized and saved: BacterialSpot(2694).JPG to 224x224
#     Resized and saved: BacterialSpot(2011).jpg to 224x224
#     Resized and saved: BacterialSpot(1967).jpg to 224x224
#     Resized and saved: BacterialSpot(511).JPG to 224x224
# ...
#     Resized and saved: YellowLeafCurl(445).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2225).JPG to 224x224
#     Resized and saved: YellowLeafCurl(309).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1316).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1334).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1769).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2505).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1197).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1618).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1354).JPG to 224x224
#     Resized and saved: YellowLeafCurl(829).JPG to 224x224
#     Resized and saved: YellowLeafCurl(119).JPG to 224x224
#     Resized and saved: YellowLeafCurl(973).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1941).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1994).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1083).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1913).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1993).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1710).JPG to 224x224
#     Resized and saved: YellowLeafCurl(702).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1720).JPG to 224x224
#     Resized and saved: YellowLeafCurl(864).JPG to 224x224
#     Resized and saved: YellowLeafCurl(570).JPG to 224x224
#     Resized and saved: YellowLeafCurl(517).jpg to 224x224
#     Resized and saved: YellowLeafCurl(372).JPG to 224x224
#     Resized and saved: YellowLeafCurl(948).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1917).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2139).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1304).JPG to 224x224
#     Resized and saved: YellowLeafCurl(589).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1870).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1716).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1251).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1380).JPG to 224x224
#     Resized and saved: YellowLeafCurl(259).jpg to 224x224
#     Resized and saved: YellowLeafCurl(1517).JPG to 224x224
#     Resized and saved: YellowLeafCurl(531).jpg to 224x224
#     Resized and saved: YellowLeafCurl(2515).jpg to 224x224
#     Resized and saved: YellowLeafCurl(2420).JPG to 224x224
#     Resized and saved: YellowLeafCurl(281).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1233).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2206).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1683).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1634).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2327).JPG to 224x224
#     Resized and saved: YellowLeafCurl(730).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1298).JPG to 224x224
#     Resized and saved: YellowLeafCurl(903).JPG to 224x224
#     Resized and saved: YellowLeafCurl(703).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2135).JPG to 224x224
#     Resized and saved: YellowLeafCurl(645).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2474).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1863).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1851).jpg to 224x224
#     Resized and saved: YellowLeafCurl(2286).JPG to 224x224
#     Resized and saved: YellowLeafCurl(314).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2457).JPG to 224x224
#     Resized and saved: YellowLeafCurl(701).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2295).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1724).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1607).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2034).JPG to 224x224
#     Resized and saved: YellowLeafCurl(786).JPG to 224x224
#     Resized and saved: YellowLeafCurl(377).JPG to 224x224
#     Resized and saved: YellowLeafCurl(789).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1407).JPG to 224x224
#     Resized and saved: YellowLeafCurl(940).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2061).JPG to 224x224
#     Resized and saved: YellowLeafCurl(112).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1617).JPG to 224x224
#     Resized and saved: YellowLeafCurl(273).JPG to 224x224
#     Resized and saved: YellowLeafCurl(772).JPG to 224x224
#     Resized and saved: YellowLeafCurl(107).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1761).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1397).JPG to 224x224
#     Resized and saved: YellowLeafCurl(15).JPG to 224x224
#     Resized and saved: YellowLeafCurl(296).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1877).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1482).JPG to 224x224
#     Resized and saved: YellowLeafCurl(876).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1885).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2312).JPG to 224x224
#     Resized and saved: YellowLeafCurl(949).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1641).JPG to 224x224
#     Resized and saved: YellowLeafCurl(510).JPG to 224x224
#     Resized and saved: YellowLeafCurl(461).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2254).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2377).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1392).JPG to 224x224
#     Resized and saved: YellowLeafCurl(962).JPG to 224x224
#     Resized and saved: YellowLeafCurl(689).JPG to 224x224
#     Resized and saved: YellowLeafCurl(734).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1446).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2015).JPG to 224x224
#     Resized and saved: YellowLeafCurl(212).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1573).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2084).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1428).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2468).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1849).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1286).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1241).JPG to 224x224
#     Resized and saved: YellowLeafCurl(133).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2226).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1951).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2247).JPG to 224x224
#     Resized and saved: YellowLeafCurl(486).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2504).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1898).JPG to 224x224
#     Resized and saved: YellowLeafCurl(935).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1678).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1593).JPG to 224x224
#     Resized and saved: YellowLeafCurl(268).JPG to 224x224
#     Resized and saved: YellowLeafCurl(828).JPG to 224x224
#     Resized and saved: YellowLeafCurl(809).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2224).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1968).JPG to 224x224
#     Resized and saved: YellowLeafCurl(857).JPG to 224x224
#     Resized and saved: YellowLeafCurl(383).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1069).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2057).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1335).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1764).JPG to 224x224
#     Resized and saved: YellowLeafCurl(670).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2376).JPG to 224x224
#     Resized and saved: YellowLeafCurl(290).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2337).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2006).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1524).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2368).JPG to 224x224
#     Resized and saved: YellowLeafCurl(129).jpg to 224x224
#     Resized and saved: YellowLeafCurl(1391).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2314).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1410).JPG to 224x224
#     Resized and saved: YellowLeafCurl(721).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2154).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1403).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2178).JPG to 224x224
#     Resized and saved: YellowLeafCurl(586).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1896).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1259).JPG to 224x224
#     Resized and saved: YellowLeafCurl(524).jpg to 224x224
#     Resized and saved: YellowLeafCurl(1670).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2198).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1923).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1979).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1978).JPG to 224x224
#     Resized and saved: YellowLeafCurl(242).JPG to 224x224
#     Resized and saved: YellowLeafCurl(672).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1337).JPG to 224x224
#     Resized and saved: YellowLeafCurl(664).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2194).JPG to 224x224
#     Resized and saved: YellowLeafCurl(562).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1733).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1504).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1278).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1431).JPG to 224x224
#     Resized and saved: YellowLeafCurl(754).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2175).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2437).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1172).JPG to 224x224
#     Resized and saved: YellowLeafCurl(83).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2402).JPG to 224x224
#     Resized and saved: YellowLeafCurl(274).JPG to 224x224
#     Resized and saved: YellowLeafCurl(955).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1864).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2421).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2019).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1704).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1265).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1159).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2358).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2107).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1057).JPG to 224x224
#     Resized and saved: YellowLeafCurl(756).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2514).jpg to 224x224
#     Resized and saved: YellowLeafCurl(139).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2408).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1037).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2395).JPG to 224x224
#     Resized and saved: YellowLeafCurl(732).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1528).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2533).jpg to 224x224
#     Resized and saved: YellowLeafCurl(339).JPG to 224x224
#     Resized and saved: YellowLeafCurl(235).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2429).JPG to 224x224
#     Resized and saved: YellowLeafCurl(984).JPG to 224x224
#     Resized and saved: YellowLeafCurl(376).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1975).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2).JPG to 224x224
#     Resized and saved: YellowLeafCurl(431).JPG to 224x224
#     Resized and saved: YellowLeafCurl(230).JPG to 224x224
#     Resized and saved: YellowLeafCurl(114).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2455).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2114).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1034).JPG to 224x224
#     Resized and saved: YellowLeafCurl(787).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1465).JPG to 224x224
#     Resized and saved: YellowLeafCurl(996).JPG to 224x224
#     Resized and saved: YellowLeafCurl(669).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1759).JPG to 224x224
#     Resized and saved: YellowLeafCurl(304).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1592).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2088).JPG to 224x224
#     Resized and saved: YellowLeafCurl(345).JPG to 224x224
#     Resized and saved: YellowLeafCurl(389).JPG to 224x224
#     Resized and saved: YellowLeafCurl(182).JPG to 224x224
#     Resized and saved: YellowLeafCurl(880).JPG to 224x224
#     Resized and saved: YellowLeafCurl(863).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1766).JPG to 224x224
#     Resized and saved: YellowLeafCurl(998).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1443).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2446).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1584).JPG to 224x224
#     Resized and saved: YellowLeafCurl(440).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1561).JPG to 224x224
#     Resized and saved: YellowLeafCurl(897).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1293).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1967).JPG to 224x224
#     Resized and saved: YellowLeafCurl(741).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1327).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1884).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1805).JPG to 224x224
#     Resized and saved: YellowLeafCurl(93).JPG to 224x224
#     Resized and saved: YellowLeafCurl(544).jpg to 224x224
#     Resized and saved: YellowLeafCurl(2240).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1245).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2350).JPG to 224x224
#     Resized and saved: YellowLeafCurl(708).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1401).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1614).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1213).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1004).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2193).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2365).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1564).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1726).JPG to 224x224
#     Resized and saved: YellowLeafCurl(869).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2063).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1767).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1537).JPG to 224x224
#     Resized and saved: YellowLeafCurl(160).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1277).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2160).JPG to 224x224
#     Resized and saved: YellowLeafCurl(956).JPG to 224x224
#     Resized and saved: YellowLeafCurl(237).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2162).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1252).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2459).JPG to 224x224
#     Resized and saved: YellowLeafCurl(783).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1970).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1124).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1020).JPG to 224x224
#     Resized and saved: YellowLeafCurl(747).JPG to 224x224
#     Resized and saved: YellowLeafCurl(121).JPG to 224x224
#     Resized and saved: YellowLeafCurl(718).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2372).JPG to 224x224
#     Resized and saved: YellowLeafCurl(37).JPG to 224x224
#     Resized and saved: YellowLeafCurl(2215).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1606).JPG to 224x224
#     Resized and saved: YellowLeafCurl(541).jpg to 224x224
#     Resized and saved: YellowLeafCurl(1743).JPG to 224x224
#     Resized and saved: YellowLeafCurl(685).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1848).JPG to 224x224
#     Resized and saved: YellowLeafCurl(265).JPG to 224x224
#     Resized and saved: YellowLeafCurl(825).JPG to 224x224
#     Resized and saved: YellowLeafCurl(398).JPG to 224x224
#     Resized and saved: YellowLeafCurl(1054).JPG to 224x224
#   Finished processing /media/tairo/Storages/AIProject/AboutModel/TraAI/Data/train/Yellow Leaf Curl.
#   Successfully resized: 1775 images.
#   Failed to process: 0 images.
# ----------------------------------------
# ==================================================
# Image resizing process complete.
